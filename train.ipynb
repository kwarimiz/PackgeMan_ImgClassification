# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
import torchvision.models as models
from torchsummary import summary
from config.root_path import DATA_ROOT
from urllib.request import urlopen
from PIL import Image
import torch.nn.functional as F
from models.maxvit_modify import maxvit_custom
from models.model import get_model
from modules.train_utils import DataHandler
from torchvision import models as model_loader
import timm
device = torch.device('cuda:0')
from torchsummary import summary

# %%
from flash_attn import flash_attn_qkvpacked_func,flash_attn_func

# %%
x = torch.randn(64,3,224,224)

# %%
model = get_model('maxvit', 8)
# Out:
# /home/wangcheng/anaconda3/envs/sd/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
model = maxvit_custom()
# Out:
# /home/wangcheng/anaconda3/envs/sd/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# 定义 hook 函数
def hook_fn(module, input, output, name):
    print(f"{name} ({module.__class__.__name__}) 输出 shape: {output.shape}")

# 定义递归注册 hooks 的函数
def register_hooks(model, hook_fn, hooks_list, prefix=''):
    for name, module in model.named_children():
        full_name = f"{prefix}.{name}" if prefix else name
        hooks_list.append(module.register_forward_hook(lambda m, inp, out, name=full_name: hook_fn(m, inp, out, name)))
        register_hooks(module, hook_fn, hooks_list, prefix=full_name)

# 注册所有 hooks
hooks = []
register_hooks(model, hook_fn, hooks)

# %%
# 定义 Hook 函数
def hook_fn(module, input, output):
    print(f'{module} 输出 shape: {output.shape}')

# 为每一层添加 hook
hook_handles = []
for layer in model.children():
    handle = layer.register_forward_hook(hook_fn)
    hook_handles.append(handle)

# %%
x = torch.randn(1, 3, 224, 224)
y = model(x)
# Out:
# stem.0.0 (Conv2d) 输出 shape: torch.Size([1, 64, 112, 112])
# stem.0.1 (BatchNorm2d) 输出 shape: torch.Size([1, 64, 112, 112])
# stem.0.2 (GELU) 输出 shape: torch.Size([1, 64, 112, 112])
# stem.0 (Conv2dNormActivation) 输出 shape: torch.Size([1, 64, 112, 112])
# stem.1.0 (Conv2d) 输出 shape: torch.Size([1, 64, 112, 112])
# stem.1 (Conv2dNormActivation) 输出 shape: torch.Size([1, 64, 112, 112])
# stem (Sequential) 输出 shape: torch.Size([1, 64, 112, 112])
# Sequential(
#   (0): Conv2dNormActivation(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#   )
#   (1): Conv2dNormActivation(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# ) 输出 shape: torch.Size([1, 64, 112, 112])
# blocks.0.layers.0.layers.ScConv.DSC.depthwise (Conv2d) 输出 shape: torch.Size([1, 64, 56, 56])
# ...

# %%
root_path = os.path.join(DATA_ROOT,'8_class_select')

data_transform = {
        "train": transforms.Compose([transforms.CenterCrop(256),
                                     transforms.Resize(224),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                    ]),
        "val": transforms.Compose([
                                   transforms.CenterCrop(256),
                                   transforms.Resize(224),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                   ])
                }

# %%
batch_size = 64
lr = 0.0001
nw = min([os.cpu_count(), batch_size if batch_size > 1 else 0, 8])  # number of workers
print('Using {} dataloader workers every process\n'.format(nw))


train_dataset = datasets.ImageFolder(os.path.join(root_path,'train'),
                                     transform=data_transform['train'])

train_loader = DataLoader(train_dataset,
                          batch_size = batch_size,                         
                          shuffle=True,
                          num_workers = nw)

val_dataset = datasets.ImageFolder(os.path.join(root_path,'val'),
                                   transform=data_transform['val'])
val_loader = DataLoader(val_dataset,
                        batch_size = batch_size,
                        shuffle=False,
                        num_workers = nw)
# Out:
# Using 8 dataloader workers every process

# %%
net = get_model('maxvit',num_classes=8)

# %%
net = maxvit_custom()
# Out:
# /home/wangcheng/anaconda3/envs/sd/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
net.to(device)
# Out:
# MaxVit(
#   (stem): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=0.001, momentum=0.99, affine=True, track_running_stats=True)
#       (2): GELU(approximate='none')
#     )
#     (1): Conv2dNormActivation(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (blocks): ModuleList(
#     (0): MaxVitBlock(
#       (layers): ModuleList(
#         (0): MaxVitLayer(
#           (layers): Sequential(
#             (ScConv): ScConv(
#               (DSC): DepthwiseSeparableConv(
#                 (depthwise): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#                 (pointwise): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (SRU): SRU(
#                 (gn): GroupNorm(4, 64, eps=1e-05, affine=True)
#                 (sigomid): Sigmoid()
# ...

# %%
loss_funtion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(),lr=0.001)

# %%
for epoch in range(10):
    net.train()
    running_loss = 0.0
    for i,data in enumerate(train_loader):
        inputs,labels = data
        inputs,labels = inputs.to(device),labels.to(device)
        
        optimizer.zero_grad()
        outputs = net(inputs)
        
        loss = loss_funtion(outputs,labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        print(running_loss/len(train_loader))
# Out:
# cuda:0 cuda:0
# cuda:0
# 0.011154759189356928
# cuda:0 cuda:0
# cuda:0
# 0.02308601659277211
# cuda:0 cuda:0
# cuda:0
# 0.036374182804771095
# cuda:0 cuda:0
# cuda:0
# 0.05106022435685863
# cuda:0 cuda:0
# cuda:0
# 0.0637888156849405
# cuda:0 cuda:0
# cuda:0
# 0.07584329662115677
# cuda:0 cuda:0
# cuda:0
# 0.08859772656274878
# cuda:0 cuda:0
# cuda:0
# 0.10092774422272392
# cuda:0 cuda:0
# cuda:0
# 0.11396004583524622
# cuda:0 cuda:0
# cuda:0
# 0.1257003947444584
# cuda:0 cuda:0
# cuda:0
# 0.13718750165856403
# cuda:0 cuda:0
# cuda:0
# 0.1486320664053378
# cuda:0 cuda:0
# cuda:0
# 0.16079973267472308
# cuda:0 cuda:0
# cuda:0
# 0.17222498422083649
# cuda:0 cuda:0
# cuda:0
# 0.18370788641597913
# cuda:0 cuda:0
# cuda:0
# 0.19542590690695721
# cuda:0 cuda:0
# cuda:0
# 0.20669623172801474
# cuda:0 cuda:0
# cuda:0
# 0.21778942709383758
# cuda:0 cuda:0
# cuda:0
# 0.22936251241227854
# cuda:0 cuda:0
# cuda:0
# 0.2403392986111019
# cuda:0 cuda:0
# cuda:0
# 0.2516131077123725
# cuda:0 cuda:0
# ...
